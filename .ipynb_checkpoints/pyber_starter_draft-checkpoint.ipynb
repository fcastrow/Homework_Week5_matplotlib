# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# File to Load (Remember to change these)
city_data_to_load = "data/city_data.csv"
ride_data_to_load = "data/ride_data.csv"

# Read the City and Ride Data
city_data = pd.read_csv(city_data_to_load)
#columns: city driver_count type
ride_data = pd.read_csv(ride_data_to_load)
#columns: city date fare ride_id

# Combine the data into a single dataset
#city_ride_df = pd.merge(city_data, ride_data, on='city', how='outer')
city_ride_df = pd.merge(ride_data, city_data, on=['city','city'], how='left')

# Display the data table for preview
city_ride_df.head()

#city_ride_df["type"].value_counts()
#Urban       1625
#Suburban     625
#Rural        125
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2018-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2018-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2018-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2018-03-06 04:28:35  34.58  3908451377344
#
#    driver_count   type
# 0             5  Urban
# 1            72  Urban
# 2            57  Urban
# 3            34  Urban
# 4            46  Urban

# %% [markdown]
# ## Bubble Plot of Ride Sharing Data

# %%
# Obtain the x and y coordinates for each of the three city types
urban_city_ride_df = city_ride_df[city_ride_df["type"]=="Urban"]
urban_city_ride_gb = urban_city_ride_df.groupby(["city"])

suburban_city_ride_df = city_ride_df[city_ride_df["type"]=="Suburban"]
suburban_city_ride_gb = suburban_city_ride_df.groupby(["city"])

rural_city_ride_df = city_ride_df[city_ride_df["type"]=="Rural"]
rural_city_ride_gb = rural_city_ride_df.groupby(["city"])

# Build the scatter plots for each city types
x_axis_u = urban_city_ride_gb["ride_id"].count()
data_u = urban_city_ride_gb["fare"].mean()
plt.scatter(x_axis_u,data_u,marker='o',facecolors='Coral',edgecolors='black',s=urban_city_ride_df["driver_count"]*5,
            alpha=.5, label="Urban")

x_axis_s = suburban_city_ride_gb["ride_id"].count()
data_s = suburban_city_ride_gb["fare"].mean()
plt.scatter(x_axis_s,data_s,marker='o',facecolors='SkyBlue',edgecolors='black',s=suburban_city_ride_df["driver_count"]*5,
            alpha=.5, label="Suburban")

x_axis_r = rural_city_ride_gb["ride_id"].count()
data_r = rural_city_ride_gb["fare"].mean()
plt.scatter(x_axis_r,data_r,marker='o',facecolors='Gold',edgecolors='black',s=rural_city_ride_df["driver_count"]*5,
            alpha=.5, label="Rural")

# Incorporate the other graph properties
plt.title("Pyber Ride Sharing Data (2016)")
plt.xlabel("Total Number of Rides (Per City)")
plt.ylabel("Average Fare ($)")
plt.grid(True)

# Create a legend
lgnd = plt.legend(title="City Types", fontsize="small", loc="best")
lgnd.legendHandles[0]._sizes = [30]
lgnd.legendHandles[1]._sizes = [30]
lgnd.legendHandles[2]._sizes = [30]

# Incorporate a text label regarding circle size
textstr = "Note:\nCircle size correlates with driver count per city."
plt.text(42, 35, textstr, fontsize=10)

# Save Figure
plt.savefig("Pyber_ScatterPlot.png")

# %%
print(urban_city_ride_gb.head())
print(urban_city_ride_gb["driver_count"])
# Out:
#                     city                 date   fare        ride_id  \
# 0     Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1     South Michelleport  2018-03-04 18:24:09  30.24  2343912425577
# 2     Port Samanthamouth  2018-02-24 04:29:00  33.44  2005065760003
# 3             Rodneyfort  2018-02-10 23:22:03  23.44  5149245426178
# 4             South Jack  2018-03-06 04:28:35  34.58  3908451377344
# 5           South Latoya  2018-03-11 12:26:48   9.52  1994999424437
# 6          New Paulville  2018-02-27 11:17:56  43.25   793208410091
# 7           Simpsonburgh  2018-04-26 00:43:24  35.98   111953927754
# 8        South Karenland  2018-01-08 03:28:48  35.09  7995623208694
# 9          North Jasmine  2018-03-09 06:26:29  42.81  5327642267789
# 10   New Kimberlyborough  2018-02-07 01:10:11   9.34  7992781920789
# 11           West Angela  2018-01-12 01:45:27  26.86  4820052223501
# 12            Rodneyfort  2018-03-02 18:03:20  44.26  2494064867705
# 13           West Angela  2018-01-10 12:17:31  12.74  2108723916092
# 14           Roberthaven  2018-05-04 14:48:56  25.66  1026197778354
# 15           North Jason  2018-03-28 22:28:44   9.19  7007022521141
# 16          Williamsview  2018-01-03 16:19:25  18.93  1979492913169
# 17               Leahton  2018-02-26 18:42:15   8.85  6966668662612
# 18          West Anthony  2018-03-06 02:27:01  10.02  9396763280782
# 19   New Kimberlyborough  2018-04-25 22:58:38  29.67  4823568522144
# 20           Roberthaven  2018-02-24 10:26:34   7.80  2180566685151
# 21           New Paulton  2018-05-01 03:12:49   8.28  8527101897862
# 22   West Patrickchester  2018-03-19 05:46:20  40.86   898889456779
# 23             Deanville  2018-04-25 03:29:09  41.52  6055928921559
# 24       West Josephberg  2018-02-19 16:22:09  36.39  3322126516683
# 25      West Samuelburgh  2018-05-03 14:33:41  41.12  7330842806458
# 26            West Heidi  2018-03-14 23:46:50  24.40  4908573010166
# 27             Loganberg  2018-04-01 01:06:03   8.23   678728883160
# 28           Huntermouth  2018-02-10 23:32:13  25.79  1880379662035
# 29          South Latoya  2018-01-11 18:44:14  27.41  8662301917375
# ..                   ...                  ...    ...            ...
# 393        Port Johnbury  2018-04-11 10:26:44   9.10  7804751879143
# 397         South Latoya  2018-03-19 16:19:22  31.72   363818381250
# 398           Robertport  2018-02-18 15:01:19  43.47  7995689882173
# 403          Richardfort  2018-04-17 02:26:37  23.00   720020655850
# 404          Hurleymouth  2018-02-20 10:47:47  17.07  7023698303898
# 418            Karenberg  2018-03-05 01:38:53  44.10  9226782716583
# 423        Martinezhaven  2018-02-07 21:45:45   4.31  9333328117367
# 427            Pattyland  2018-04-03 03:29:52  14.06  5399011565161
# 431         Reynoldsfurt  2018-01-17 21:35:17  24.84  5000179618056
# 437            Rogerston  2018-03-24 02:56:21  39.60  9196190355530
# 438            Karenberg  2018-04-27 14:57:38  44.73  3800715746753
# 450        Port Johnbury  2018-05-02 12:46:00  42.42  3245384693395
# 454          Amandaburgh  2018-01-21 04:12:54   9.26  5528427024492
# 463           Robertport  2018-04-03 01:20:38  15.14  6669724727514
# 474        West Ericstad  2018-03-28 13:29:17  22.28  3135272644045
# 478           Robertport  2018-02-28 22:50:15  13.39   681044064878
# 482          Barajasview  2018-02-19 02:25:34  26.83   937248382509
# 484        North Barbara  2018-04-17 02:49:28  39.18  3503287273107
# 488              Johnton  2018-04-05 07:12:55  22.87  1030619542522
# 490         Reynoldsfurt  2018-04-19 00:56:32  13.63  7990078064277
# 519            Rogerston  2018-03-16 20:49:51  43.82  4718959573846
# 528        North Barbara  2018-02-11 18:51:20  43.26  8973500869212
# 529            Rogerston  2018-03-02 00:54:29  25.14  1722619288127
# 567         West Gabriel  2018-01-15 14:51:33  13.38  7560918647139
# 639            Erikaland  2018-02-21 20:28:30  12.44  2705086825803
# 662              Johnton  2018-03-15 08:40:23  43.50  7134200570421
# 795         West Gabriel  2018-04-21 04:50:53   4.96  2694140247746
# 798         West Gabriel  2018-01-16 06:23:21  25.97  6590477525761
# 803         West Gabriel  2018-05-01 02:18:03  27.45  2827457582877
# 824         Reynoldsfurt  2018-04-11 09:09:53  42.97  1390651031898
#
#      driver_count   type
# 0               5  Urban
# 1              72  Urban
# 2              57  Urban
# 3              34  Urban
# 4              46  Urban
# 5              10  Urban
# 6              44  Urban
# 7              21  Urban
# 8               4  Urban
# 9              33  Urban
# 10             33  Urban
# 11             48  Urban
# 12             34  Urban
# 13             48  Urban
# 14             47  Urban
# 15              6  Urban
# 16             46  Urban
# 17             17  Urban
# 18             70  Urban
# 19             33  Urban
# 20             47  Urban
# 21             44  Urban
# 22             25  Urban
# 23             49  Urban
# 24             45  Urban
# 25             73  Urban
# 26             28  Urban
# 27             23  Urban
# 28             37  Urban
# 29             10  Urban
# ..            ...    ...
# 393             3  Urban
# 397            10  Urban
# 398            12  Urban
# 403            38  Urban
# 404            36  Urban
# 418            22  Urban
# 423            25  Urban
# 427            59  Urban
# 431            67  Urban
# 437            25  Urban
# 438            22  Urban
# 450             3  Urban
# 454            12  Urban
# 463            12  Urban
# 474            25  Urban
# 478            12  Urban
# 482            26  Urban
# 484            18  Urban
# 488            27  Urban
# 490            67  Urban
# 519            25  Urban
# 528            18  Urban
# 529            25  Urban
# 567            57  Urban
# 639            37  Urban
# 662            27  Urban
# 795            57  Urban
# 798            57  Urban
# 803            57  Urban
# 824            67  Urban
#
# [330 rows x 6 columns]
# <pandas.core.groupby.generic.SeriesGroupBy object at 0x000001D28C2997B8>

# %%
# Show plot
plt.show()

# %% [markdown]
# ## Total Fares by City Type

# %%
#Calculate Type Percents
urban_pct = urban_city_ride_df["fare"].sum()/city_ride_df["fare"].count() 
suburban_pct = suburban_city_ride_df["fare"].sum()/city_ride_df["fare"].count() 
rural_pct = rural_city_ride_df["fare"].sum()/city_ride_df["fare"].count()

#Build Pie Chart
labels = ["Urban","Rural","Suburban"]
sizes = [urban_pct,rural_pct,suburban_pct] 
colors = ["Coral","Gold","SkyBlue"]
explode = (.1,0,0)

plt.pie(sizes,explode=explode,labels=labels,colors=colors,shadow=True,startangle=290, autopct="%1.1f%%") 
plt.axis("auto")
plt.title("% of Total Fares by City Type")

#Save Figure
plt.savefig("Pyber_TFCT_Pie.png")

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Rides by City Type

# %%
# Calculate Ride Percents
urban_ride_pct = urban_city_ride_df["ride_id"].count()/city_ride_df["ride_id"].count()
suburban_ride_pct = suburban_city_ride_df["ride_id"].count()/city_ride_df["ride_id"].count()
rural_ride_pct = rural_city_ride_df["ride_id"].count()/city_ride_df["ride_id"].count()

sizes = [urban_ride_pct,rural_ride_pct,suburban_ride_pct] 

# Build Pie Chart
plt.pie(sizes,explode=explode,labels=labels,colors=colors,shadow=True,startangle=270, autopct="%1.1f%%")
plt.axis("auto")
plt.title("% of Total Rides by City Type")

# Save Figure
plt.savefig("Pyber_TRCT_Pie.png")

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Drivers by City Type

# %%
# Calculate Driver Percents
total_driver_count = city_data["driver_count"].sum()

urban_city_df = city_data[city_data["type"]=="Urban"]
urban_driver_count = urban_city_df["driver_count"].sum()
urban_driver_pct = (urban_driver_count/total_driver_count)

suburban_city_df = city_data[city_data["type"]=="Suburban"]
suburban_driver_count = suburban_city_df["driver_count"].sum()
suburban_driver_pct = (suburban_driver_count/total_driver_count)

rural_city_df = city_data[city_data["type"]=="Rural"]
rural_driver_count = rural_city_df["driver_count"].sum()
rural_driver_pct = (rural_driver_count/total_driver_count)

sizes = [urban_driver_pct,rural_driver_pct,suburban_driver_pct] 

# Build Pie Charts
plt.pie(sizes,explode=explode,labels=labels,colors=colors,shadow=True,startangle=240, autopct="%1.1f%%")
plt.axis("auto")
plt.title("% of Total Drivers by City Type")

# Save Figure
plt.savefig("Pyber_TDCT_Pie.png")

# %%
# Show Figure
plt.show()
